# %%
# Write a Python program for Don't go Outside in Odd day

# Number of Days = [1,2,3,4,5,6,7,8,9]
odd=0
even=0
for i in range (1,10):
  if i%2==0:
    even=even+1
  else:
    odd=odd+1
print("number of even numbers:",even,)
print("number of odd numbers:",odd)
# Out:
# number of even numbers: 4
# number of odd numbers: 5
